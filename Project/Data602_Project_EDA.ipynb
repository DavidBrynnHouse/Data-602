# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1e524ad0-ffaf-47e4-b583-1e7453327263" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1e524ad0-ffaf-47e4-b583-1e7453327263">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Crashes_in_DC.csv to Crashes_in_DC.csv

# %%
df = pd.read_csv('Crashes_in_DC.csv')
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            X          Y  ...  MINORINJURIESPASSENGER  UNKNOWNINJURIESPASSENGER
# 0 -77.007754  38.835717  ...                       0                         0
# 1 -77.103886  38.939821  ...                       0                         0
# 2 -77.031957  38.902531  ...                       0                         0
# 3 -77.036076  38.933146  ...                       0                         0
# 4 -77.006367  38.908292  ...                       0                         0
#
# [5 rows x 60 columns]

# %%
df['FATAL_BICYCLIST'].value_counts()
# Out:
# 0    259361
# 1        13
# Name: FATAL_BICYCLIST, dtype: int64

# %%
df['FATAL_PEDESTRIAN'].value_counts()
# Out:
# 0    259262
# 1       110
# 2         2
# Name: FATAL_PEDESTRIAN, dtype: int64

# %%
df['FATALPASSENGER'].value_counts()
# Out:
# 0    259297
# 1        73
# 2         4
# Name: FATALPASSENGER, dtype: int64

# %% [markdown]
# The data is very sparse (thankfully). However, I think there are enough points to create a classification for this project.

# %%
df.describe()
# Out:
#                    X  ...  UNKNOWNINJURIESPASSENGER
# count  259374.000000  ...             259374.000000
# mean      -76.365028  ...                  0.009353
# std         6.596734  ...                  0.130620
# min       -78.815503  ...                  0.000000
# 25%       -77.031956  ...                  0.000000
# 50%       -77.009159  ...                  0.000000
# 75%       -76.983445  ...                  0.000000
# max        77.012717  ...                 15.000000
#
# [8 rows x 47 columns]

# %% [markdown]
# I hope to be able to use the classifier to determine where fatal accidents are most common, and what times and speeds they occur at. This information could be useful in redesigning roads and rules to prevent traffic deaths.

# %%
print(df.hist(figsize=(15, 15)))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc8401a5790>
# ...
